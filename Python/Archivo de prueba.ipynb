# %% [markdown]
# # ARCHIVO NUEVO

# %%
mi_archivo= open('new.txt')

# %%
mi_archivo
# Out:
# <_io.TextIOWrapper name='new.txt' mode='r' encoding='cp1252'>

# %%
mi_archivo.read()
# Out:
# 'Crear nuevo archivo'

# %%
mi_archivo.seek(0)
# Out:
# 0

# %%
mi_archivo.read()
# Out:
# 'Crear nuevo archivo'

# %%
mi_archivo
# Out:
# <_io.TextIOWrapper name='new.txt' mode='r' encoding='cp1252'>

# %%
mi_archivo.seek(0)
mi_archivo.readlines()
# Out:
# ['Crear nuevo archivo']

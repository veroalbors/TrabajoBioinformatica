# %% [markdown]
# # Taller Estructura de datos
#
# ### Resuelve las siguientes preguntas empleando lo aprendido con las estructuras de Datos

# %% [markdown]
# Pon el código debajo de cada pregunta. Añade tantas celdas de código como necesites.

# %% [markdown]
# #### 1.- Escribe una ecuación que emplee multiplicación, división, un exponente, suma y resta y que sea igual a 427,85.

# %%
((427.85*1)/1)*1**1+0-0
# Out:
# 427.85

# %%
70*6 + 8 - 0.15**1
# Out:
# 427.85

# %% [markdown]
# #### 2.- ¿Qué harías para obtener la raíz cuadrada de 100? Busca dos formas.

# %%
100 ** (1/2)
# Out:
# 10.0

# %%
100**0.5
# Out:
# 10.0

# %%
# Buscar función sqrt()
import math
print(math.sqrt(100))
# Out:
# 10.0

# %% [markdown]
# #### 3.- ¿Y el cuadrado de 100?

# %%
100**2
# Out:
# 10000

# %%
import math
math.pow(100,2)
# Out:
# 10000.0

# %% [markdown]
# #### 4.- Tenemos la string 'hello'.
# #### Primero devuelve la letra 'e'
# #### Luego dale la vuelta a la string
# #### Después usa dos métodos para devolver la letra 'o'

# %%
s = 'hello'

# %%
s[1]
# Out:
# 'e'

# %%
s[::-1]
# Out:
# 'olleh'

# %%
s[4]
# Out:
# 'o'

# %%
s[4:]
# Out:
# 'o'

# %%
s[-1]
# Out:
# 'o'

# %%
s[len(s)-1]
# Out:
# 'o'

# %% [markdown]
# #### 5.- Crear una lista que contenga esto [0,0,0] de dos formas distintas.

# %%
lista = [0,0,0]
lista
# Out:
# [0, 0, 0]

# %%
[0] * 3
# Out:
# [0, 0, 0]

# %%
lista=[0]
lista*3
# Out:
# [0, 0, 0]

# %% [markdown]
# #### 6.- Reasigna 'hello' en la lista a continuación para que diga 'goodbye'.

# %%
lista = [1,2,[3,4,'hello']]

# %%
lista[2][2] ="goodbye"

# %%
lista
# Out:
# [1, 2, [3, 4, 'goodbye']]

# %% [markdown]
# #### 7.- Ordena la siguiente lista.

# %%
listaSinOrdenar = [5,3,4,6,1]

# %%
listaSinOrdenar.sort()

# %%
listaSinOrdenar
# Out:
# [1, 3, 4, 5, 6]

# %% [markdown]
# #### 8.- En los siguientes diccionarios, extrae el valor de 'hello'.

# %%
f = {'k1':{'k2':'hello'}}

# %%
f["k1"]
# Out:
# {'k2': 'hello'}

# %%
d = {'key1':'hello'}

# %%
d["key1"]
# Out:
# 'hello'

# %%
g = {'k1':[{'o1':['valor escondido',['hello']]}]}

# %%
g["k1"][0]["o1"][1][0]
# Out:
# 'hello'

# %%
h = {'k1':[1,2,{'k2':['complicado',{'dificil':[1,2,['hello']]}]}]}

# %%
h["k1"][2]["k2"][1]["dificil"][2][0]
# Out:
# 'hello'

# %% [markdown]
# #### 9.- Crea una tupla.

# %%
t = (1,2,3)

# %%
t
# Out:
# (1, 2, 3)

# %% [markdown]
# #### 10.- Emplea los sets para encontrar los valores únicos de esta lista.

# %%
listaDuplicada = [1,2,2,33,4,4,11,22,3,3,2]

# %%
set(listaDuplicada)
# Out:
# {1, 2, 3, 4, 11, 22, 33}

# %% [markdown]
# #### 11.- Haz las siguientes comparaciones:
# #### Dos mayor que tres
# #### Tres igual que 2
# #### La raíz cuadrada de cuatro no es igual a 2
# #### Se cumple si 6 es mayor que 5 y 7 menor de 8
# #### Se cumple si la longitud de _nombre_ es  que el número de elementos de _colores_ o si la longitud de _nombre_ es menor de 7.

# %%
# 2 mayor que 3
2 > 2
# Out:
# False

# %%
# 3 igual que 2
3 == 2
# Out:
# False

# %%
# raíz cuadrada de 4 no es igual a 2
4**0.5 !=2
# Out:
# False

# %%
nombre = "Pepito"
colores = ["azul","rojo","verde","lila","amarillo limón"]

len(nombre) == len(colores) or len(nombre) <7
# Out:
# True

# %% [markdown]
# #### 12.- Crea un archivo mediante código que se llame _tabla-nombres.txt_ y que esté formado por 4 columnas y 4 filas con la siguiente formación:
# #### Primera columna: Nombre
# #### Segunda columna: Apellidos (2 apellidos)
# #### Tercera columna: Edad
# #### Cuarta columna: Mascotas (nombre de la mascota si tienen)
#
# #### ¿Qué pasa si abres el archivo desde Jupyter y has metido acentos? ¿Puedes solucionarlo?

# %%
archivo = open("tabla-nombres.txt","wt")

# %%
archivo
# Out:
# <_io.TextIOWrapper name='tabla-nombres.txt' mode='wt' encoding='cp1252'>

# %%
archivo.write("Nombre\Apellidos\Edad\Mascotas\n")
# Out:
# 31

# %%
archivo.write("Juan\tMorgade Díaz\t2\Pinto\n")
archivo.write("Vero\tAlbors\t5\tCaty")
# Out:
# 18

# %%
archivo.sent(0)

# %% [markdown]
# #### 13.- Crea un diccionario que contenga las siguientes parejas. Obtén el listado de keys() y guárdalo en una lista. Añade un par de elementos más y después convierte esa lista en un set.
#
# #### *Rattus* = *novergicus*, *rattus*
# #### *Glaucidium* = *brasilianum*, *hoskinsii*, *californicum*, *minutissimum*
# #### *Echinocactus* = *grusonii*
# #### *Opuntia* = *ficus-indica*

# %%
d = {}
d["Rattus"] = ["novergicus", "rattus"]
d["Glaucidium"] = ["brasilianum","hoskinsii","californicum","minutissimum"]
d["Echinocactus"] = "grusonii"
d["Opuntia"] = 1

# %%
lista_ids = list(d.keys())
lista_ids
# Out:
# ['Rattus', 'Glaucidium', 'Echinocactus', 'Opuntia']

# %%
# otra forma de añadir es lista_ids.append("Calopteryx") para el primero por ejemplo
# la forma extendida de la de debajo es lista_ids = lista_ids + ["Calopteryx","Apus"]
lista_ids += ["Calopteryx","Apus"]

# %%
lista_ids
# Out:
# ['Rattus', 'Glaucidium', 'Echinocactus', 'Opuntia', 'Calopteryx', 'Apus']

# %%
lista_ids = set(lista_ids)

# %%
lista_ids
# Out:
# {'Apus', 'Calopteryx', 'Echinocactus', 'Glaucidium', 'Opuntia', 'Rattus'}
